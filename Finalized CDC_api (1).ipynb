# %% [markdown]
# # Part 3: Covid Precautionary Measures Sentiment

# %% [markdown]
# ### Context:
# When considering how a person responds to the pandemic, whether it be wearing masks in public or getting the COVID vaccine, we were interested in learning about how one's political affiliation may play a role in their willingness to adhere to state mandates. After looking at several subreddits (specific communities on Reddit) on COVID-related posts, there seems to be a difference in sentiment towards the pandemic for Republicans and Democrats. In order to get a comprehensive understanding of the differences in response, we analyzed data throughout the course of the entire pandemic in addition to recent statistics.
#
#
# ### Method:
# Looking at state data using several APIs, we web scraped the information into dataframes containing relevant information. The CDC provides a extensive number of datasets that can be retrieved from the Open Data Source API. For number of cases specifically, we used the Covid Act Now API to obtain the time series for two of the largest states in the United States with polarized political values, California ($\color{blue}{\text{Dem}}$) and Texas ($\color{red}{\text{Rep}}$).
#
# To evaluate the relationship between vaccination rate and political affiliation, we referred to the CDC's data on vaccine hesitancy for counties in America along with the majority political party identification of each state from Wikipedia's *Political party strength in U.S. states* page.

# %%
import requests
import pandas as pd
import numpy as np
import lxml.html as lx
import seaborn as sns
sns.set_style("darkgrid")


import matplotlib.pyplot as plt

# %%
key = "455a847e8a92464f98ece023015975ff"

# %%
import json
allstates = requests.get("https://api.covidactnow.org/v2/states.timeseries.json?apiKey=455a847e8a92464f98ece023015975ff")
data = json.loads(allstates.text)
ca_df = pd.json_normalize(data[4]) # normalize CA data from the list of all json
tx_df = pd.json_normalize(data[45]) # normalize TX data
ca_ts = pd.json_normalize(ca_df["actualsTimeseries"][0]) # select times series json from CA
tx_ts = pd.json_normalize(tx_df["actualsTimeseries"][0]) # select times series json from TX

# %% [markdown]
# Because population size is a major influence on number of total cases, we normalized the data using the states' populations.

# %%
def pop_normalize(case, pop):
    return case/pop*100000 # return incidence rate

# %%
ca_ts["Cases Per 100K"] = [pop_normalize(case, ca_df.population) for case in ca_ts["cases"]]
ca_ts["Cases Per 100K"] = [ca_ts["Cases Per 100K"][i][0] for i in range(len(ca_ts["Cases Per 100K"]))] # select numeric
                                                                                                        # incidence rate
tx_ts["Cases Per 100K"] = [pop_normalize(case, tx_df.population) for case in tx_ts["cases"]]
tx_ts["Cases Per 100K"] = [tx_ts["Cases Per 100K"][i][0] for i in range(len(tx_ts["Cases Per 100K"]))]
ca_ts["date"] = pd.to_datetime(ca_ts["date"])
tx_ts["date"] = pd.to_datetime(tx_ts["date"])
ca_ts["state"] = "CA"
tx_ts["state"] = "TX"

# %% [markdown]
# Though there were many NaN values scattered throughout the dataset, we can still refer to the relevant columns (cases & deaths) without dropping these rows.

# %%
joint_df = pd.concat([ca_ts, tx_ts], ignore_index=True) # stack both dataframes 
joint_df
# Out:
#           cases   deaths  positiveTests  negativeTests  contactTracers  \
# 0           1.0      0.0            NaN            NaN             NaN
# 1           2.0      0.0            NaN            NaN             NaN
# 2           2.0      0.0            NaN            NaN             NaN
# 3           2.0      0.0            NaN            NaN             NaN
# 4           2.0      0.0            NaN            NaN             NaN
# ...         ...      ...            ...            ...             ...
# 1535  6560264.0  86117.0      6691227.0     41414333.0             NaN
# 1536  6566067.0  86266.0      6691264.0     41415902.0             NaN
# 1537  6574225.0  86366.0            NaN            NaN             NaN
# 1538  6577325.0  86455.0            NaN            NaN             NaN
# 1539  6578428.0  86491.0            NaN            NaN             NaN
#
#       newCases  newDeaths vaccinesAdministeredDemographics  \
# 0          NaN        NaN                             None
# 1          1.0        0.0                             None
# 2          0.0        0.0                             None
# 3          0.0        0.0                             None
# 4          0.0        0.0                             None
# ...        ...        ...                              ...
# 1535    5132.0      126.0                             None
# 1536    5803.0      149.0                             None
# 1537    8158.0      100.0                             None
# 1538    3100.0       89.0                             None
# 1539    1103.0       36.0                             None
#
#      vaccinationsInitiatedDemographics       date  ...  icuBeds.capacity  \
# 0                                 None 2020-01-25  ...               NaN
# 1                                 None 2020-01-26  ...               NaN
# 2                                 None 2020-01-27  ...               NaN
# 3                                 None 2020-01-28  ...               NaN
# 4                                 None 2020-01-29  ...               NaN
# ...                                ...        ...  ...               ...
# 1535                              None 2022-03-09  ...            6258.0
# 1536                              None 2022-03-10  ...            6298.0
# 1537                              None 2022-03-11  ...            6694.0
# 1538                              None 2022-03-12  ...            6694.0
# 1539                              None 2022-03-13  ...            6694.0
#
#       icuBeds.currentUsageTotal  icuBeds.currentUsageCovid  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 1535                     5597.0                      560.0
# 1536                     5564.0                      526.0
# 1537                     5612.0                      494.0
# 1538                     5618.0                      490.0
# 1539                     5618.0                      490.0
#
#       vaccinesDistributed  vaccinationsInitiated  vaccinationsCompleted  \
# 0                     NaN                    NaN                    NaN
# 1                     NaN                    NaN                    NaN
# 2                     NaN                    NaN                    NaN
# 3                     NaN                    NaN                    NaN
# 4                     NaN                    NaN                    NaN
# ...                   ...                    ...                    ...
# 1535           59201895.0             20710121.0             17486305.0
# 1536           59247995.0             20723606.0             17494744.0
# 1537           59363595.0             20715479.0             17486035.0
# 1538           59363595.0             20727169.0             17493588.0
# 1539           59363595.0             20733407.0             17500458.0
#
#       vaccinationsAdditionalDose  vaccinesAdministered  Cases Per 100K  state
# 0                            NaN                   NaN        0.002531     CA
# 1                            NaN                   NaN        0.005062     CA
# 2                            NaN                   NaN        0.005062     CA
# 3                            NaN                   NaN        0.005062     CA
# 4                            NaN                   NaN        0.005062     CA
# ...                          ...                   ...             ...    ...
# 1535                   6303638.0            44661265.0    22624.813504     TX
# 1536                   6312461.0            44693438.0    22644.826691     TX
# 1537                   6316692.0            44726431.0    22672.961722     TX
# 1538                   6325014.0            44755582.0    22683.652895     TX
# 1539                   6332292.0            44777465.0    22687.456884     TX
#
# [1540 rows x 23 columns]

# %% [markdown]
# Using a line plot to examine the incidence rate over the course of the pandemic (changes in growth rates at each point in time will be the slope of the curves). Line plots are optimal for displaying time series data, clearly showing changes in growth of case rates each quarter starting from January 2020.

# %%
sns.lineplot(x=joint_df.date, y=joint_df["Cases Per 100K"], hue=joint_df["state"],
             palette=["blue", 'red']).set_title("Incidence Rate Over Time").get_figure().autofmt_xdate()

# %%
from scipy.stats import ttest_ind
stat, p = ttest_ind(ca_ts["Cases Per 100K"].dropna(), tx_ts["Cases Per 100K"].dropna()) # drop rows with NaN for both states
print(stat, p) # return t-stat of case rates
# Out:
# -2.3070487905818493 0.02118490789324234

# %% [markdown]
# We perform a Student's t test to see if there is a true different in mean incidence rates for the two states. The negative t-statistic, -2.3070487905818493, indicates that California had a lower mean incidence rate over the course of the pandemic. We conclude that the two states did not have the same mean incidence rate because our p-value of 0.02118490789324234 is significant.

# %%
import requests
def get_df(url): # function for obtaining DFs from CDC API json links
    response = requests.get(url)
    html = lx.fromstring(response.text)
    paragraphs = html.xpath("//p")
    content = [paragraph.text_content() for paragraph in paragraphs]
    df = pd.read_json(content[0])
    return df

# %% [markdown]
# The CDC provided information on county hesitancy rates based on Household Pulse Survey responses. A response of "1" corresponds to "definitely getting the vaccine" and a response of "5" means "definitely not getting the vaccine."

# %%
hesitancy = pd.read_json("https://data.cdc.gov/api/id/q9mh-h2tw.json")
hesitancy
# Out:
#      fips_code                 county_name    state  estimated_hesitant  \
# 0         1123  Tallapoosa County, Alabama  ALABAMA              0.1806
# 1         1121   Talladega County, Alabama  ALABAMA              0.1783
# 2         1131      Wilcox County, Alabama  ALABAMA              0.1735
# 3         1129  Washington County, Alabama  ALABAMA              0.1735
# 4         1133     Winston County, Alabama  ALABAMA              0.1805
# ..         ...                         ...      ...                 ...
# 995      20003     Anderson County, Kansas   KANSAS              0.1560
# 996      19029           Cass County, Iowa     IOWA              0.1323
# 997      19171           Tama County, Iowa     IOWA              0.1293
# 998      19085       Harrison County, Iowa     IOWA              0.1323
# 999      19173         Taylor County, Iowa     IOWA              0.1362
#
#      estimated_hesitant_or_unsure  estimated_strongly_hesitant  \
# 0                          0.2400                       0.1383
# 1                          0.2350                       0.1368
# 2                          0.2357                       0.1337
# 3                          0.2357                       0.1337
# 4                          0.2313                       0.1379
# ..                            ...                          ...
# 995                        0.2068                       0.0963
# 996                        0.1905                       0.0795
# 997                        0.1877                       0.0781
# 998                        0.1905                       0.0795
# 999                        0.1966                       0.0841
#
#      social_vulnerability_index             svi_category  \
# 0                          0.89  Very High Vulnerability
# 1                          0.87  Very High Vulnerability
# 2                          0.93  Very High Vulnerability
# 3                          0.73       High Vulnerability
# 4                          0.70       High Vulnerability
# ..                          ...                      ...
# 995                        0.23        Low Vulnerability
# 996                        0.20   Very Low Vulnerability
# 997                        0.33        Low Vulnerability
# 998                        0.06   Very Low Vulnerability
# 999                        0.28        Low Vulnerability
#
#      ability_to_handle_a_covid      cvac_category  ...  \
# 0                         0.64       High Concern  ...
# 1                         0.84  Very High Concern  ...
# 2                         0.94  Very High Concern  ...
# 3                         0.82  Very High Concern  ...
# 4                         0.80       High Concern  ...
# ..                         ...                ...  ...
# 995                       0.63       High Concern  ...
# 996                       0.09   Very Low Concern  ...
# 997                       0.10   Very Low Concern  ...
# 998                       0.02   Very Low Concern  ...
# 999                       0.14   Very Low Concern  ...
#
#      percent_non_hispanic_asian  percent_non_hispanic_black  \
# 0                        0.0036                      0.2697
# 1                        0.0061                      0.3237
# 2                        0.0003                      0.6938
# 3                        0.0025                      0.2354
# 4                        0.0016                      0.0073
# ..                          ...                         ...
# 995                      0.0001                      0.0050
# 996                      0.0028                      0.0020
# 997                      0.0046                      0.0092
# 998                      0.0049                      0.0019
# 999                      0.0102                      0.0002
#
#      percent_non_hispanic_native  percent_non_hispanic_white  \
# 0                         0.0000                      0.6887
# 1                         0.0003                      0.6263
# 2                         0.0000                      0.2684
# 3                         0.0000                      0.6495
# 4                         0.0005                      0.9370
# ..                           ...                         ...
# 995                       0.0000                      0.9484
# 996                       0.0014                      0.9529
# 997                       0.0000                      0.8075
# 998                       0.0004                      0.9620
# 999                       0.0000                      0.9038
#
#                                     geographical_point  state_code  \
# 0    {'type': 'Point', 'coordinates': [-86.844516, ...          AL
# 1    {'type': 'Point', 'coordinates': [-86.844516, ...          AL
# 2    {'type': 'Point', 'coordinates': [-86.844516, ...          AL
# 3    {'type': 'Point', 'coordinates': [-86.844516, ...          AL
# 4    {'type': 'Point', 'coordinates': [-86.844516, ...          AL
# ..                                                 ...         ...
# 995  {'type': 'Point', 'coordinates': [-98.38018, 3...          KS
# 996  {'type': 'Point', 'coordinates': [-93.500061, ...          IA
# 997  {'type': 'Point', 'coordinates': [-93.500061, ...          IA
# 998  {'type': 'Point', 'coordinates': [-93.500061, ...          IA
# 999  {'type': 'Point', 'coordinates': [-93.500061, ...          IA
#
#                                        county_boundary  \
# 0    {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# 1    {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# 2    {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# 3    {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# 4    {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# ..                                                 ...
# 995  {'type': 'MultiPolygon', 'coordinates': [[[[-9...
# 996  {'type': 'MultiPolygon', 'coordinates': [[[[-9...
# 997  {'type': 'MultiPolygon', 'coordinates': [[[[-9...
# 998  {'type': 'MultiPolygon', 'coordinates': [[[[-9...
# 999  {'type': 'MultiPolygon', 'coordinates': [[[[-9...
#
#                                         state_boundary  \
# 0    {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# 1    {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# 2    {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# 3    {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# 4    {'type': 'MultiPolygon', 'coordinates': [[[[-8...
# ..                                                 ...
# 995  {'type': 'MultiPolygon', 'coordinates': [[[[-1...
# 996  {'type': 'MultiPolygon', 'coordinates': [[[[-9...
# 997  {'type': 'MultiPolygon', 'coordinates': [[[[-9...
# 998  {'type': 'MultiPolygon', 'coordinates': [[[[-9...
# 999  {'type': 'MultiPolygon', 'coordinates': [[[[-9...
#
#     :@computed_region_hjsp_umg2 :@computed_region_skr5_azej
# 0                            29                          94
# 1                            29                          94
# 2                            29                          94
# 3                            29                          94
# 4                            29                          94
# ..                          ...                         ...
# 995                          17                        1287
# 996                          16                         299
# 997                          16                         299
# 998                          16                         299
# 999                          16                         299
#
# [1000 rows x 23 columns]

# %% [markdown]
# The COVID Data Tracker from the CDC also establishes the number of doses delivered for each state.

# %%
#https://covid.cdc.gov/covid-data-tracker/#vaccinations_vacc-total-admin-rate-total
vaccination = pd.read_csv("C:\\Users\\chris\\Documents\\STA 141B\\covid19_vaccinations_in_the_united_states.csv")
vaccination.columns = vaccination.iloc[3,:] # column names are in third row
vaccination = vaccination.iloc[4:,:] # remove the blank first rows
vaccination['State/Territory/Federal Entity'] = [state.lower() for state in vaccination['State/Territory/Federal Entity']]
vaccination                                                 # lower state names for merging dfs
# Out:
# 3  State/Territory/Federal Entity Total Doses Delivered  \
# 4                   united states             689797945
# 5                          alaska               1443865
# 6                         alabama               9252240
# 7                        arkansas               5858220
# 8                  american samoa                 92810
# ..                            ...                   ...
# 63                        vermont               1697650
# 64                     washington              16837495
# 65                      wisconsin              11082845
# 66                  west virginia               3849485
# 67                        wyoming                934385
#
# 3  Doses Delivered per 100K 18+ Doses Delivered per 100K  \
# 4                    207765                       267095
# 5                    197372                       261777
# 6                    188699                       242530
# 7                    194122                       252766
# 8                    195835                       296186
# ..                      ...                          ...
# 63                   272064                       332883
# 64                   221113                       282896
# 65                   190347                       243267
# 66                   214797                       268710
# 67                   161446                       209962
#
# 3  Total Doses Administered by State where Administered  \
# 4                                           552526931
# 5                                             1093935
# 6                                             6094167
# 7                                             4085165
# 8                                               87449
# ..                                                ...
# 63                                            1345762
# 64                                           13839196
# 65                                            9858587
# 66                                            2634424
# 67                                             730635
#
# 3  Doses Administered per 100k by State where Administered  \
# 4                                              166419
# 5                                              149538
# 6                                              124290
# 7                                              135369
# 8                                              184523
# ..                                                ...
# 63                                             215671
# 64                                             181739
# 65                                             169321
# 66                                             146998
# 67                                             126242
#
# 3  18+ Doses Administered by State where Administered  \
# 4                                           500683736
# 5                                              983376
# 6                                             5695106
# 7                                             3730583
# 8                                               63896
# ..                                                ...
# 63                                            1207850
# 64                                           12491888
# 65                                            8998372
# 66                                            2465598
# 67                                             677714
#
# 3  18+ Doses Administered per 100K by State where Administered  \
# 4                                              193868
# 5                                              178289
# 6                                              149287
# 7                                              160964
# 8                                              203913
# ..                                                ...
# 63                                             236841
# 64                                             209883
# 65                                             197513
# 66                                             172109
# 67                                             152287
#
# 3  People with at least One Dose by State of Residence  \
# 4                                           253395029
# 5                                              500935
# 6                                             3033599
# 7                                             1982981
# 8                                               42783
# ..                                                ...
# 63                                             577604
# 64                                            6069678
# 65                                            4136395
# 66                                            1150072
# 67                                             335542
#
# 3  Percent of Total Pop with at least One Dose by State of Residence  ...  \
# 4                                                76.3                 ...
# 5                                                68.5                 ...
# 6                                                61.9                 ...
# 7                                                65.7                 ...
# 8                                                90.3                 ...
# ..                                                ...                 ...
# 63                                               92.6                 ...
# 64                                               79.7                 ...
# 65                                                 71                 ...
# 66                                               64.2                 ...
# 67                                                 58                 ...
#
# 3  Percent People Primary Moderna Booster J&J  \
# 4                                         0.1
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# ..                                        ...
# 63                                        NaN
# 64                                        NaN
# 65                                        NaN
# 66                                        NaN
# 67                                        NaN
#
# 3  Percent People Primary Moderna Booster Other  \
# 4                                             0
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# ..                                          ...
# 63                                          NaN
# 64                                          NaN
# 65                                          NaN
# 66                                          NaN
# 67                                          NaN
#
# 3  Percent People Primary J&J Booster Pfizer  \
# 4                                       34.1
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# ..                                       ...
# 63                                       NaN
# 64                                       NaN
# 65                                       NaN
# 66                                       NaN
# 67                                       NaN
#
# 3  Percent People Primary J&J Booster Moderna  \
# 4                                        41.4
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# ..                                        ...
# 63                                        NaN
# 64                                        NaN
# 65                                        NaN
# 66                                        NaN
# 67                                        NaN
#
# 3  Percent People Primary J&J Booster J&J  \
# 4                                    24.4
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# ..                                    ...
# 63                                    NaN
# 64                                    NaN
# 65                                    NaN
# 66                                    NaN
# 67                                    NaN
#
# 3  Percent People Primary J&J Booster Other  \
# 4                                         0
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# ..                                      ...
# 63                                      NaN
# 64                                      NaN
# 65                                      NaN
# 66                                      NaN
# 67                                      NaN
#
# 3  Percent People Primary Other Booster Pfizer  \
# 4                                         51.4
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# ..                                         ...
# 63                                         NaN
# 64                                         NaN
# 65                                         NaN
# 66                                         NaN
# 67                                         NaN
#
# 3  Percent People Primary Other Booster Moderna  \
# 4                                            43
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# ..                                          ...
# 63                                          NaN
# 64                                          NaN
# 65                                          NaN
# 66                                          NaN
# 67                                          NaN
#
# 3  Percent People Primary Other Booster J&J  \
# 4                                       0.3
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# ..                                      ...
# 63                                      NaN
# 64                                      NaN
# 65                                      NaN
# 66                                      NaN
# 67                                      NaN
#
# 3  Percent People Primary Other Booster Uknown
# 4                                          5.2
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# ..                                         ...
# 63                                         NaN
# 64                                         NaN
# 65                                         NaN
# 66                                         NaN
# 67                                         NaN
#
# [64 rows x 125 columns]

# %% [markdown]
# Wikipedia includes several tables highlighting different political strengths for states in the U.S. We specifically chose to look at poltical party identification majorities in each state.

# %%
import urllib.request as urlrq
import certifi
import ssl

resp = urlrq.urlopen("https://en.wikipedia.org/wiki/Political_party_strength_in_U.S._states", 
                     context=ssl.create_default_context(cafile=certifi.where()))

# %%
ssl._create_default_https_context = ssl._create_unverified_context # bypass certification requirement
lst= pd.read_html("https://en.wikipedia.org/wiki/Political_party_strength_in_U.S._states") # read in tables

# %% [markdown]
# The party identification column includes number detailing the split between parties, which must be cleaned up for clear party majority assignment.

# %%
def clean_party(states): # remove irrelavant details of party identification
    if "Republican" in states:
        return "Republican"
    elif "Democratic" in states:
        return "Democratic"
    else:
        return "Even"

# %%
df = pd.DataFrame(lst[5]) # make df out of table of interest (6th)
df = df.rename(columns={"State": "state", 'Party registration or identification (% as of 2020': "Party identification"})
df["Party identification"] = [clean_party(state) for state in df["Party identification"]]
df
# Out:
#              state              2020 presidentialelection    Governor  \
# 0          Alabama                             Republican  Republican
# 1           Alaska                             Republican  Republican
# 2          Arizona                             Democratic  Republican
# 3         Arkansas                             Republican  Republican
# 4       California                             Democratic  Democratic
# 5         Colorado                             Democratic  Democratic
# 6      Connecticut                             Democratic  Democratic
# 7         Delaware                             Democratic  Democratic
# 8          Florida                             Republican  Republican
# 9          Georgia                             Democratic  Republican
# 10          Hawaii                             Democratic  Democratic
# 11           Idaho                             Republican  Republican
# 12        Illinois                             Democratic  Democratic
# 13         Indiana                             Republican  Republican
# 14            Iowa                             Republican  Republican
# 15          Kansas                             Republican  Democratic
# 16        Kentucky                             Republican  Democratic
# 17       Louisiana                             Republican  Democratic
# 18           Maine  Democratic/ Republican (2nd District)  Democratic
# 19        Maryland                             Democratic  Republican
# 20   Massachusetts                             Democratic  Republican
# 21        Michigan                             Democratic  Democratic
# 22       Minnesota                             Democratic  Democratic
# 23     Mississippi                             Republican  Republican
# 24        Missouri                             Republican  Republican
# 25         Montana                             Republican  Republican
# 26        Nebraska  Republican/ Democratic (2nd District)  Republican
# 27          Nevada                             Democratic  Democratic
# 28   New Hampshire                             Democratic  Republican
# 29      New Jersey                             Democratic  Democratic
# 30      New Mexico                             Democratic  Democratic
# 31        New York                             Democratic  Democratic
# 32  North Carolina                             Republican  Democratic
# 33    North Dakota                             Republican  Republican
# 34            Ohio                             Republican  Republican
# 35        Oklahoma                             Republican  Republican
# 36          Oregon                             Democratic  Democratic
# 37    Pennsylvania                             Democratic  Democratic
# 38    Rhode Island                             Democratic  Democratic
# 39  South Carolina                             Republican  Republican
# 40    South Dakota                             Republican  Republican
# 41       Tennessee                             Republican  Republican
# 42           Texas                             Republican  Republican
# 43            Utah                             Republican  Republican
# 44         Vermont                             Democratic  Republican
# 45        Virginia                             Democratic  Republican
# 46      Washington                             Democratic  Democratic
# 47   West Virginia                             Republican  Republican
# 48       Wisconsin                             Democratic  Democratic
# 49         Wyoming                             Republican  Republican
#
#                                          State Senate  \
# 0                                     Republican 27–8
# 1                                     Republican 13–7
# 2                                    Republican 16–14
# 3                                     Republican 28–7
# 4                                     Democratic 31–9
# 5                                    Democratic 20–15
# 6                                    Democratic 24–12
# 7                                     Democratic 14–7
# 8                                    Republican 24–16
# 9                                    Republican 34–22
# 10                                    Democratic 24–1
# 11                                    Republican 28–7
# 12                                   Democratic 41–18
# 13                                   Republican 39–11
# 14                                   Republican 32–18
# 15                                Republican 29–11[d]
# 16                                    Republican 30–8
# 17                                   Republican 27–12
# 18                                   Democratic 22–13
# 19                                   Democratic 32–15
# 20                                    Democratic 37–3
# 21                                   Republican 22–16
# 22                                 Republican 34–31–2
# 23                                   Republican 36–16
# 24                                   Republican 24–10
# 25                                   Republican 31–19
# 26  Unicameral Nonpartisan Legislature[f](De facto...
# 27                                    Democratic 12–9
# 28                                   Republican 14–10
# 29                                   Democratic 24–16
# 30                              Democratic 26–15-1[g]
# 31                                   Democratic 43–20
# 32                                   Republican 28–22
# 33                                    Republican 40–7
# 34                                    Republican 25–8
# 35                                    Republican 39–9
# 36                                   Democratic 18–12
# 37                                 Republican 28–21–1
# 38                                    Democratic 33–5
# 39                                   Republican 30–16
# 40                                    Republican 32–3
# 41                                    Republican 27–6
# 42                                   Republican 18–13
# 43                                    Republican 23–6
# 44                               Democratic 21–7–2[d]
# 45                                Democratic 21–18[d]
# 46                                   Democratic 28–21
# 47                                   Republican 23–11
# 48                                   Republican 21–12
# 49                                    Republican 28–2
#
#                                           State House SeniorU.S. Senator  \
# 0                                    Republican 77–28         Republican
# 1                                  Coalition 23–17[b]         Republican
# 2                                    Republican 31–29         Democratic
# 3                                    Republican 77–23         Republican
# 4                                  Democratic 59–19–1         Democratic
# 5                                    Democratic 41–24         Democratic
# 6                                    Democratic 97–54         Democratic
# 7                                    Democratic 26–15         Democratic
# 8                                    Republican 78–42         Republican
# 9                                   Republican 103–77         Democratic
# 10                                    Democratic 47–4         Democratic
# 11                                   Republican 58–12         Republican
# 12                                   Democratic 73–45         Democratic
# 13                                   Republican 71–29         Republican
# 14                                   Republican 59–41         Republican
# 15                                   Republican 86–39         Republican
# 16                                   Republican 75–25         Republican
# 17                              Republican 68–35–2[d]         Republican
# 18                              Democratic 80–67–4[d]         Republican
# 19                                   Democratic 99–42         Democratic
# 20                             Democratic 129–30–1[d]         Democratic
# 21                                   Republican 58–52         Democratic
# 22                                   Democratic 70–64         Democratic
# 23                              Republican 75–44–3[d]         Republican
# 24                                  Republican 116–47         Republican
# 25                                   Republican 67–33         Democratic
# 26  Unicameral Nonpartisan Legislature[f](De facto...         Republican
# 27                                   Democratic 26–16         Democratic
# 28                                 Republican 213–187         Democratic
# 29                                   Democratic 46–34         Democratic
# 30                                   Democratic 45–25         Democratic
# 31                             Democratic 106–43–1[d]         Democratic
# 32                                   Republican 69–51         Republican
# 33                                   Republican 80–14         Republican
# 34                                   Republican 64–35         Democratic
# 35                                   Republican 82–19         Republican
# 36                                   Democratic 37–23         Democratic
# 37                                  Republican 112–90         Democratic
# 38                                   Democratic 65–10         Democratic
# 39                                   Republican 81–43         Republican
# 40                                    Republican 62–8         Republican
# 41                                   Republican 73–26         Republican
# 42                                   Republican 83–67         Republican
# 43                                   Republican 58–17         Republican
# 44                            Democratic 93–45–7–5[d]         Democratic
# 45                                   Republican 52–48         Democratic
# 46                                   Democratic 57–41         Democratic
# 47                                   Republican 76–24         Democratic
# 48                                   Republican 61–38         Republican
# 49                                Republican 51–7–1–1         Republican
#
#    JuniorU.S. Senator U.S. House of Representatives Party identification
# 0          Republican                Republican 6–1           Republican
# 1          Republican                    Republican           Republican
# 2          Democratic                Democratic 5–4           Republican
# 3          Republican                  Republican 4           Republican
# 4          Democratic              Democratic 42–11           Democratic
# 5          Democratic                Democratic 4–3           Democratic
# 6          Democratic                  Democratic 5           Democratic
# 7          Democratic                    Democratic           Democratic
# 8          Republican         Republican 16–10–1[d]           Republican
# 9          Democratic                Republican 8-6           Democratic
# 10         Democratic                  Democratic 2           Democratic
# 11         Republican                  Republican 2           Republican
# 12         Democratic               Democratic 13–5           Democratic
# 13         Republican                Republican 7–2           Republican
# 14         Republican                Republican 3–1           Democratic
# 15         Republican                Republican 3–1           Republican
# 16         Republican                Republican 5–1           Democratic
# 17         Republican                Republican 5–1           Democratic
# 18     Independent[e]                  Democratic 2           Democratic
# 19         Democratic                Democratic 7-1           Democratic
# 20         Democratic                  Democratic 9           Democratic
# 21         Democratic                      Tied 7–7           Democratic
# 22         Democratic                      Tied 4–4           Democratic
# 23         Republican                Republican 3–1           Republican
# 24         Republican                Republican 6–2           Republican
# 25         Republican                    Republican           Republican
# 26         Republican                  Republican 3           Republican
# 27         Democratic                Democratic 3–1           Democratic
# 28         Democratic                  Democratic 2           Democratic
# 29         Democratic               Democratic 10-2           Democratic
# 30         Democratic                Democratic 2–1           Democratic
# 31         Democratic               Democratic 19–8           Democratic
# 32         Republican                Republican 9–5           Democratic
# 33         Republican                    Republican           Republican
# 34         Republican               Republican 12–4           Republican
# 35         Republican                  Republican 5           Republican
# 36         Democratic                Democratic 4–1           Democratic
# 37         Republican                      Tied 9–9           Democratic
# 38         Democratic                  Democratic 2           Democratic
# 39         Republican                Republican 6–1           Republican
# 40         Republican                    Republican           Republican
# 41         Republican                Republican 7–2           Republican
# 42         Republican              Republican 23–13           Republican
# 43         Republican                  Republican 4           Republican
# 44     Independent[e]                    Democratic           Democratic
# 45         Democratic                Democratic 7–4           Democratic
# 46         Democratic                Democratic 7–3           Democratic
# 47         Republican                  Republican 3           Republican
# 48         Democratic                Republican 5–3                 Even
# 49         Republican                    Republican           Republican

# %%
df['state'] = [state.lower() for state in df['state']] # lower for df merging
hesitancy['state'] = [state.lower() for state in hesitancy['state']]

# %%
corr_df = hesitancy.merge(df, on='state') # combine the dfs on state name
corr_df
# Out:
#      fips_code                 county_name    state  estimated_hesitant  \
# 0         1123  Tallapoosa County, Alabama  alabama              0.1806
# 1         1121   Talladega County, Alabama  alabama              0.1783
# 2         1131      Wilcox County, Alabama  alabama              0.1735
# 3         1129  Washington County, Alabama  alabama              0.1735
# 4         1133     Winston County, Alabama  alabama              0.1805
# ..         ...                         ...      ...                 ...
# 994      19029           Cass County, Iowa     iowa              0.1323
# 995      19171           Tama County, Iowa     iowa              0.1293
# 996      19085       Harrison County, Iowa     iowa              0.1323
# 997      19173         Taylor County, Iowa     iowa              0.1362
# 998      20003     Anderson County, Kansas   kansas              0.1560
#
#      estimated_hesitant_or_unsure  estimated_strongly_hesitant  \
# 0                          0.2400                       0.1383
# 1                          0.2350                       0.1368
# 2                          0.2357                       0.1337
# 3                          0.2357                       0.1337
# 4                          0.2313                       0.1379
# ..                            ...                          ...
# 994                        0.1905                       0.0795
# 995                        0.1877                       0.0781
# 996                        0.1905                       0.0795
# 997                        0.1966                       0.0841
# 998                        0.2068                       0.0963
#
#      social_vulnerability_index             svi_category  \
# 0                          0.89  Very High Vulnerability
# 1                          0.87  Very High Vulnerability
# 2                          0.93  Very High Vulnerability
# 3                          0.73       High Vulnerability
# 4                          0.70       High Vulnerability
# ..                          ...                      ...
# 994                        0.20   Very Low Vulnerability
# 995                        0.33        Low Vulnerability
# 996                        0.06   Very Low Vulnerability
# 997                        0.28        Low Vulnerability
# 998                        0.23        Low Vulnerability
#
#      ability_to_handle_a_covid      cvac_category  ...  \
# 0                         0.64       High Concern  ...
# 1                         0.84  Very High Concern  ...
# 2                         0.94  Very High Concern  ...
# 3                         0.82  Very High Concern  ...
# 4                         0.80       High Concern  ...
# ..                         ...                ...  ...
# 994                       0.09   Very Low Concern  ...
# 995                       0.10   Very Low Concern  ...
# 996                       0.02   Very Low Concern  ...
# 997                       0.14   Very Low Concern  ...
# 998                       0.63       High Concern  ...
#
#      :@computed_region_hjsp_umg2  :@computed_region_skr5_azej  \
# 0                             29                           94
# 1                             29                           94
# 2                             29                           94
# 3                             29                           94
# 4                             29                           94
# ..                           ...                          ...
# 994                           16                          299
# 995                           16                          299
# 996                           16                          299
# 997                           16                          299
# 998                           17                         1287
#
#      2020 presidentialelection    Governor         State Senate  \
# 0                   Republican  Republican      Republican 27–8
# 1                   Republican  Republican      Republican 27–8
# 2                   Republican  Republican      Republican 27–8
# 3                   Republican  Republican      Republican 27–8
# 4                   Republican  Republican      Republican 27–8
# ..                         ...         ...                  ...
# 994                 Republican  Republican     Republican 32–18
# 995                 Republican  Republican     Republican 32–18
# 996                 Republican  Republican     Republican 32–18
# 997                 Republican  Republican     Republican 32–18
# 998                 Republican  Democratic  Republican 29–11[d]
#
#           State House  SeniorU.S. Senator JuniorU.S. Senator  \
# 0    Republican 77–28          Republican         Republican
# 1    Republican 77–28          Republican         Republican
# 2    Republican 77–28          Republican         Republican
# 3    Republican 77–28          Republican         Republican
# 4    Republican 77–28          Republican         Republican
# ..                ...                 ...                ...
# 994  Republican 59–41          Republican         Republican
# 995  Republican 59–41          Republican         Republican
# 996  Republican 59–41          Republican         Republican
# 997  Republican 59–41          Republican         Republican
# 998  Republican 86–39          Republican         Republican
#
#     U.S. House of Representatives Party identification
# 0                  Republican 6–1           Republican
# 1                  Republican 6–1           Republican
# 2                  Republican 6–1           Republican
# 3                  Republican 6–1           Republican
# 4                  Republican 6–1           Republican
# ..                            ...                  ...
# 994                Republican 3–1           Democratic
# 995                Republican 3–1           Democratic
# 996                Republican 3–1           Democratic
# 997                Republican 3–1           Democratic
# 998                Republican 3–1           Republican
#
# [999 rows x 31 columns]

# %% [markdown]
# We take the average over counties of each state using panda's groupby.

# %%
vaccination = vaccination.rename(columns={'State/Territory/Federal Entity':'state'})
corr_df = corr_df.merge(vaccination, on = 'state')
final = corr_df.groupby(['state', 'Party identification', 'Doses Delivered per 100K']).estimated_hesitant.mean()
final       # groupby states and return the estimated mean hesitancy for each state state
# Out:
# state          Party identification  Doses Delivered per 100K
# alabama        Republican            188699                      0.173507
# alaska         Republican            197372                      0.217386
# arizona        Republican            193468                      0.159240
# arkansas       Republican            194122                      0.212123
# california     Democratic            217234                      0.072274
# colorado       Democratic            205989                      0.078220
# connecticut    Democratic            232655                      0.056987
# delaware       Democratic            227936                      0.059433
# florida        Republican            212403                      0.145212
# georgia        Democratic            194463                      0.161815
# hawaii         Democratic            234299                      0.059500
# idaho          Republican            179758                      0.192023
# illinois       Democratic            206425                      0.096085
# indiana        Republican            187366                      0.131075
# iowa           Democratic            197668                      0.126705
# kansas         Republican            197298                      0.156000
# kentucky       Democratic            187903                      0.193667
# maine          Democratic            237124                      0.094800
# massachusetts  Democratic            234562                      0.050133
# michigan       Democratic            200337                      0.099392
# minnesota      Democratic            212301                      0.071900
# montana        Republican            175873                      0.255586
# nebraska       Republican            194727                      0.086680
# ohio           Republican            187856                      0.140386
# tennessee      Republican            179469                      0.128233
# texas          Republican            202856                      0.120535
# virginia       Democratic            219581                      0.061400
# washington     Democratic            221113                      0.081629
# west virginia  Republican            214797                      0.104700
# wisconsin      Even                  190347                      0.156971
# Name: estimated_hesitant, dtype: float64

# %%
final_df = pd.DataFrame()
final_df['state'] = final.index.get_level_values(0) # get values from indices of groupby object
final_df['Party identification'] = final.index.get_level_values(1)
final_df['Doses Delivered per 100K'] = final.index.get_level_values(2)
final_df['Mean Estimated Hesitancy'] = final.values
final_df
# Out:
#             state Party identification Doses Delivered per 100K  \
# 0         alabama           Republican                   188699
# 1          alaska           Republican                   197372
# 2         arizona           Republican                   193468
# 3        arkansas           Republican                   194122
# 4      california           Democratic                   217234
# 5        colorado           Democratic                   205989
# 6     connecticut           Democratic                   232655
# 7        delaware           Democratic                   227936
# 8         florida           Republican                   212403
# 9         georgia           Democratic                   194463
# 10         hawaii           Democratic                   234299
# 11          idaho           Republican                   179758
# 12       illinois           Democratic                   206425
# 13        indiana           Republican                   187366
# 14           iowa           Democratic                   197668
# 15         kansas           Republican                   197298
# 16       kentucky           Democratic                   187903
# 17          maine           Democratic                   237124
# 18  massachusetts           Democratic                   234562
# 19       michigan           Democratic                   200337
# 20      minnesota           Democratic                   212301
# 21        montana           Republican                   175873
# 22       nebraska           Republican                   194727
# 23           ohio           Republican                   187856
# 24      tennessee           Republican                   179469
# 25          texas           Republican                   202856
# 26       virginia           Democratic                   219581
# 27     washington           Democratic                   221113
# 28  west virginia           Republican                   214797
# 29      wisconsin                 Even                   190347
#
#     Mean Estimated Hesitancy
# 0                   0.173507
# 1                   0.217386
# 2                   0.159240
# 3                   0.212123
# 4                   0.072274
# 5                   0.078220
# 6                   0.056987
# 7                   0.059433
# 8                   0.145212
# 9                   0.161815
# 10                  0.059500
# 11                  0.192023
# 12                  0.096085
# 13                  0.131075
# 14                  0.126705
# 15                  0.156000
# 16                  0.193667
# 17                  0.094800
# 18                  0.050133
# 19                  0.099392
# 20                  0.071900
# 21                  0.255586
# 22                  0.086680
# 23                  0.140386
# 24                  0.128233
# 25                  0.120535
# 26                  0.061400
# 27                  0.081629
# 28                  0.104700
# 29                  0.156971

# %%
final_df['Doses Delivered per 100K'] = [int(x) for x in final_df['Doses Delivered per 100K']] # change values into numbers
sns.scatterplot(x = final_df['Mean Estimated Hesitancy'], y = final_df['Doses Delivered per 100K'], 
                hue=final_df['Party identification'], 
                palette=['red', 'blue', 'gray']).set_title("Vaccine Rate vs. Hesitancy by Party")
# Out:
# Text(0.5, 1.0, 'Vaccine Rate vs. Hesitancy by Party')

# %%
from scipy.stats import pearsonr
corr, _ = pearsonr(final_df["Mean Estimated Hesitancy"], final_df["Doses Delivered per 100K"]) #return pearson correlation
corr
# Out:
# -0.7792915361789933

# %% [markdown]
# As expected, states with higher hesitancy also had lower doses delivered. There is a strong negative correlation between hesitancy and number of vaccine doses delivered overall.

# %%
final_df["Binary Party"] = [1 if row == 'Republican' else 0 for row in final_df["Party identification"]] 
                            # Create binary labels to perform correlation measure with political party

# %%
corr, _ = pearsonr(final_df["Mean Estimated Hesitancy"], final_df["Binary Party"])
corr
# Out:
# 0.5909235276025876

# %% [markdown]
# There is a strong positive correlation between political affiliation and mean estimated hesitancy. Republicans generally had higher hesitancy towards getting the COVID vaccine.

# %% [markdown]
# We now consider the incidence rates as of March 5 for all states.

# %%
# Generated march 5
last7_df = pd.read_csv("C:\\Users\\chris\\Documents\\STA 141B\\united_states_covid19_cases_deaths_and_testing_by_state.csv")
last7_df.columns = last7_df.iloc[1,:] # column names are in 2nd row 
last7_df = last7_df.iloc[1:,:] # remove blank row

# %%
last7_df = last7_df.rename(columns={'State/Territory': 'state'})
last7_df['state'] = [state.lower() for state in last7_df['state']]
last7_df
# Out:
# 1             state  Level of Community Transmission  Total Cases  \
# 1   state/territory  Level of Community Transmission  Total Cases
# 2           alabama                             high      1286317
# 3            alaska                             high       232933
# 4    american samoa                              NaN          NaN
# 5           arizona                             high      1980769
# ..              ...                              ...          ...
# 59         virginia                             high      1647027
# 60       washington                             high      1430235
# 61    west virginia                             high       492276
# 62        wisconsin                      substantial      1574581
# 63          wyoming                      substantial       155426
#
# 1   Confirmed Cases  Probable Cases  Cases in Last 7 Days  \
# 1   Confirmed Cases  Probable Cases  Cases in Last 7 Days
# 2            926826          359491                  7290
# 3                 0               0                  2085
# 4               NaN             NaN                   NaN
# 5           1754308          226461                  5517
# ..              ...             ...                   ...
# 59          1174940          472087                  8563
# 60                0               0                 14356
# 61           390520          101756                  3917
# 62          1383739          190842                  4121
# 63           122506           32920                   517
#
# 1   Case Rate per 100000  Total Deaths  Confirmed Deaths  Probable Deaths  \
# 1   Case Rate per 100000  Total Deaths  Confirmed Deaths  Probable Deaths
# 2                  26234         18568             14284             4284
# 3                  31841          1158               NaN              NaN
# 4                    NaN           NaN               NaN              NaN
# 5                  27213         27708             23633             4075
# ..                   ...           ...               ...              ...
# 59                 19296         19005             15758             3247
# 60                 18782         12025               NaN              NaN
# 61                 27468          6440               NaN              NaN
# 62                 27043         13489             12089             1400
# 63                 26855          1741              1741                0
#
# 1   ...  % Positive Last 30 Days  % Positive Last 7 Days  # Tests per 100K  \
# 1   ...  % Positive Last 30 Days  % Positive Last 7 Days  # Tests per 100K
# 2   ...                 15-19.9%                  5-7.9%        147925.971
# 3   ...                 15-19.9%                  5-7.9%       563264.5748
# 4   ...                      NaN                     NaN               NaN
# 5   ...                 15-19.9%                  5-7.9%       190941.0905
# ..  ...                      ...                     ...               ...
# 59  ...                 10-14.9%                  5-7.9%       162736.8195
# 60  ...                      NaN                     NaN       150201.0889
# 61  ...                 15-19.9%                  8-9.9%       275252.1169
# 62  ...                   8-9.9%                  3-4.9%       267552.0153
# 63  ...                 10-14.9%                  3-4.9%       234476.9614
#
# 1   Total # Tests  # Tests per 100K Last 7 Days  Total # Tests Last 7 Days  \
# 1   Total # Tests  # Tests per 100K Last 7 Days  Total # Tests Last 7 Days
# 2         7280224                        951.63                      46835
# 3         4118354                        531.35                       3885
# 4             NaN                           NaN                        NaN
# 5        14170504                        1199.8                      89042
# ..            ...                           ...                        ...
# 59       13980009                       1125.78                      96711
# 60       11555889                       1949.05                     149952
# 61        4912664                       2438.22                      43517
# 62       15605386                       1681.45                      98073
# 63        1365425                       1785.25                      10396
#
# 1   # Tests per 100K Last 30 Days  Total # Tests Last 30 Days  New Cases  \
# 1   # Tests per 100K Last 30 Days  Total # Tests Last 30 Days  New Cases
# 2                         5108.96                      251439       3366
# 3                        14041.01                      102662        701
# 4                             NaN                         NaN        NaN
# 5                         7709.51                      572154          0
# ..                            ...                         ...        ...
# 59                        6487.92                      557349       1235
# 60                        7588.85                      583857       1529
# 61                       13883.51                      247791        578
# 62                        9770.04                      569853        542
# 63                        10492.2                       61099         77
#
# 1   New Deaths
# 1   New Deaths
# 2           88
# 3            0
# 4          NaN
# 5            0
# ..         ...
# 59          49
# 60          71
# 61          13
# 62          39
# 63           0
#
# [63 rows x 25 columns]

# %%
cases_final = final_df.merge(last7_df, on='state')
cases_final["Case Rate per 100000"] = cases_final['Case Rate per 100000'].astype(int) # change case rate datatype into int 
cases_final = cases_final.rename(columns={"Case Rate per 100000": "Cases Per 100K"})

# %%
sns.scatterplot(x = cases_final['Mean Estimated Hesitancy'], y = cases_final['Cases Per 100K'], 
                hue=cases_final['Party identification'],
                palette=['red', 'blue', 'gray']).set_title("Incidence Rates vs. Hesitancy by Party")
# Out:
# Text(0.5, 1.0, 'Incidence Rates vs. Hesitancy by Party')

# %%
corr, _ = pearsonr(cases_final["Mean Estimated Hesitancy"], cases_final["Cases Per 100K"])
corr
# Out:
# 0.581533647025002

# %% [markdown]
# There is a positive correlation between vaccine hesitancy and incidence rates for states in the US.

# %%
corr, _ = pearsonr(cases_final["Binary Party"], cases_final["Cases Per 100K"])
corr
# Out:
# 0.5043996947529066

# %% [markdown]
# When considering more states, there is still a positive correlation between incidence rates and political party.
