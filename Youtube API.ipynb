# %%
from googleapiclient.discovery import build

# %%
api_key='AIzaSyApsMarj96xas7ekAIgHUoWJQEb54HAt9o'
youtube= build('youtube','v3',developerKey=api_key)

# %%
request=youtube.commentThreads().list(
part='snippet,replies',
videoId='z_d5Kq2DwTI',
maxResults=200)

# %%
request.execute()['items']
# Out:
# [{'kind': 'youtube#commentThread',
#   'etag': 'XLxCv7t3-bDbLlDLTcxbJQjrZFo',
#   'id': 'UgxnHc6xnmsWGLWsWeJ4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'n_LefSHuOJjx1zV7WQ-T6CsSzEc',
#     'id': 'UgxnHc6xnmsWGLWsWeJ4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'WE SEE YOU, FLORIDA&#39;S 6TH SURGEON GENERAL.  You are one of THEM, now.  I have to wonder if what you got is worth what you have just given.  I&#39;ll pray for you and your family.',
#      'textOriginal': "WE SEE YOU, FLORIDA'S 6TH SURGEON GENERAL.  You are one of THEM, now.  I have to wonder if what you got is worth what you have just given.  I'll pray for you and your family.",
#      'authorDisplayName': 'Liselle Parmella',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRCBq-AaQYqPd9E6tJrI4O9c0LN9ltinSc9A4WfzvSulvAiLOlRya0sKYiLj0Kz=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UC6AttnSSIyoX_TcFKsfDNOA',
#      'authorChannelId': {'value': 'UC6AttnSSIyoX_TcFKsfDNOA'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T21:52:02Z',
#      'updatedAt': '2022-02-27T21:52:02Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'KLIjN3uav2FdW8_Xu21fWpoJ6hQ',
#   'id': 'UgzmS3qFMddpWcbXwkN4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'QgfQvJOHm32Uenjh1xTrNO9TwmE',
#     'id': 'UgzmS3qFMddpWcbXwkN4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Stop spreading covid propaganda, you will be held accountable',
#      'textOriginal': 'Stop spreading covid propaganda, you will be held accountable',
#      'authorDisplayName': 'Suncoasthoast',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/c2pVrCb9XGWyRlWzRMS2dMbq62-ux7w8a0uXu4CZTqTthH1SyGBYhkwd3b_6YAPd4mxtetCo0Kg=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCztxOaSz10dl5750wrlokqg',
#      'authorChannelId': {'value': 'UCztxOaSz10dl5750wrlokqg'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 1,
#      'publishedAt': '2022-02-27T21:27:32Z',
#      'updatedAt': '2022-02-27T21:27:32Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'bExkvco6wygua5TfDLt1vqJjAAA',
#   'id': 'UgyPZkprAOUfEjalyix4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'IRN_7oyRxig5J4InanS0J3Jhhdw',
#     'id': 'UgyPZkprAOUfEjalyix4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Effective at what?',
#      'textOriginal': 'Effective at what?',
#      'authorDisplayName': 'Russell Lowry',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRle5waDUSz2TUuxXJ0T0riyrt3HerkA8R8pA=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCjUTZz615Gx6BEWF_X_rssw',
#      'authorChannelId': {'value': 'UCjUTZz615Gx6BEWF_X_rssw'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T20:58:40Z',
#      'updatedAt': '2022-02-27T20:58:40Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'jkuabOl4lXVkerZcXcxxzziCTiA',
#   'id': 'UgxLcDoKyApyQVZ2TVt4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'i8NkkJsITxZdFdA6xbxIG4kTlAg',
#     'id': 'UgxLcDoKyApyQVZ2TVt4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'It&#39;s sad that this is still a matter of discussion.....anyone still carrying on being anti vaxx are just the generic but jobs just looking for a reason to complain about anything',
#      'textOriginal': "It's sad that this is still a matter of discussion.....anyone still carrying on being anti vaxx are just the generic but jobs just looking for a reason to complain about anything",
#      'authorDisplayName': 'Sia Henderson',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/v1xCy_RCABlm-EekpQK_3C2GtZLCLwOXksh_7o_eaKq9-QkVZgXAbMavMpI5LwjxfwKx2Tnmzg=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCLQwZOWqn6pTpoWJ4IRDmbQ',
#      'authorChannelId': {'value': 'UCLQwZOWqn6pTpoWJ4IRDmbQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T20:37:11Z',
#      'updatedAt': '2022-02-27T20:37:11Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'smwV2ZReAqGMEBuPMKiROA7woKU',
#   'id': 'Ugw9Yk3itIrdYhMkJM14AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'nTwP1el2lV_KT9tE5ndJiPZiYt0',
#     'id': 'Ugw9Yk3itIrdYhMkJM14AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'NO VACCINES! ONLY DELICIOUS SKY CAKE! SKY CAKE IS MUH SHIELD!!',
#      'textOriginal': 'NO VACCINES! ONLY DELICIOUS SKY CAKE! SKY CAKE IS MUH SHIELD!!',
#      'authorDisplayName': 'Ian Lemmon',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTp04jN2EglQvqELnFKhXKnr787YREyOP_KWU_GWw=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UC_jCA_oSf-eRlg8jaI1MNYQ',
#      'authorChannelId': {'value': 'UC_jCA_oSf-eRlg8jaI1MNYQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T20:36:06Z',
#      'updatedAt': '2022-02-27T20:36:06Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': '-oqg2x-GFk3_dciseggoOOk6CR4',
#   'id': 'UgxxFTp_Kkgr39Z6gIN4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': '6-_5SBaZbeoyIDhUa3RI3hANq0Y',
#     'id': 'UgxxFTp_Kkgr39Z6gIN4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Tough to statistically measure the impact of a treatment on a virus that came with an already better than 99% survival rate.................',
#      'textOriginal': 'Tough to statistically measure the impact of a treatment on a virus that came with an already better than 99% survival rate.................',
#      'authorDisplayName': 'Skip Pryne',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRoBx_taa7OmPtP8sllhjW9asItW4z9MUVwxA=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCElCm8aunR6ncbvkItBywPA',
#      'authorChannelId': {'value': 'UCElCm8aunR6ncbvkItBywPA'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T19:36:23Z',
#      'updatedAt': '2022-02-27T19:36:23Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': '2HUxbTgbV5OToWt_7sgUL7d_SmY',
#   'id': 'UgzmGRcHJgeCatO2MAt4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': '8RIqzLbnluTOcTT1jJd-W3UZVkk',
#     'id': 'UgzmGRcHJgeCatO2MAt4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'How much they paid you?',
#      'textOriginal': 'How much they paid you?',
#      'authorDisplayName': 'Sri Nithya Parashara Nanda',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRaPqIAlBFHwFsy15WCc1DKzpQuVYLfpN-f0Wxt5w=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCSTfndMT_15mXAaWx3ZQr1g',
#      'authorChannelId': {'value': 'UCSTfndMT_15mXAaWx3ZQr1g'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T19:11:45Z',
#      'updatedAt': '2022-02-27T19:11:45Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'AzM2UykNj17_8nmo9XXN4qORMw4',
#   'id': 'UgwdoLiqo-Y4mI1BlmV4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': '1AZlQ19KZfY64_JTkQXZk6wYsiA',
#     'id': 'UgwdoLiqo-Y4mI1BlmV4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Ok, they&#39;re effective, but still not getting vaccinated, vaccinate this 🖕',
#      'textOriginal': "Ok, they're effective, but still not getting vaccinated, vaccinate this 🖕",
#      'authorDisplayName': 'No Name',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRj1MrUKHIzRM6or8FDd8_BjRZZhL2ldkz6fgGl5KFafGZSR3oZqUSRrgDMSrHM=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UC1IQSA34O45GxvO9zqwo9rw',
#      'authorChannelId': {'value': 'UC1IQSA34O45GxvO9zqwo9rw'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T19:04:00Z',
#      'updatedAt': '2022-02-27T19:04:00Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'vQxZI9OZMlgyoWXUEeTYPLGdVoQ',
#   'id': 'Ugw2IRJghbicm3gtkh14AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'GVMI9pwEkY3DVxM2Mep4yT0jeRU',
#     'id': 'Ugw2IRJghbicm3gtkh14AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Dr. Joseph dressed like the Joker',
#      'textOriginal': 'Dr. Joseph dressed like the Joker',
#      'authorDisplayName': 'Jacob Thrasher',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/oizsoBY2UrAL1VNrdLRGRdRVNlWmg5Fa1y6zoQ9VU__2KJcb-gRRy4trSypmgSot6Sx4QmzG=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCOdDRi3TklehjaqX5VO6G7Q',
#      'authorChannelId': {'value': 'UCOdDRi3TklehjaqX5VO6G7Q'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T18:57:40Z',
#      'updatedAt': '2022-02-27T18:57:40Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'RQAiKv0UG2jqw8B4-m4XSB5HvSQ',
#   'id': 'Ugxmop3H0JuREBKkIdt4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'uvNeJ19rmVwqdJVrnacnnto7fCw',
#     'id': 'Ugxmop3H0JuREBKkIdt4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Nobody should get vaccinated anymore with the CDC lying about everything.',
#      'textOriginal': 'Nobody should get vaccinated anymore with the CDC lying about everything.',
#      'authorDisplayName': 'EDWARD MARQUIS',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSCaoRhJUn3jY2gARjMzArs-R3VXRSjnW68TQ=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UChnlXNnH_6GnmbjQZo_xq8g',
#      'authorChannelId': {'value': 'UChnlXNnH_6GnmbjQZo_xq8g'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T18:55:33Z',
#      'updatedAt': '2022-02-27T18:55:33Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'uC3LVjiT81230BNps1JdwmlgHKU',
#   'id': 'UgzDmBAHFw19CjwyMzt4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'aCeloCao6X-ISlsQl0dp-JSDJqo',
#     'id': 'UgzDmBAHFw19CjwyMzt4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'He is a fool !!',
#      'textOriginal': 'He is a fool !!',
#      'authorDisplayName': 'Robert Chase',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTOCgZOZdgGsbusRwpCK_4FNzAu5vZsrfLx8w=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UC4U8QPjOzJWTuTjkg04e40Q',
#      'authorChannelId': {'value': 'UC4U8QPjOzJWTuTjkg04e40Q'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T18:51:13Z',
#      'updatedAt': '2022-02-27T18:51:13Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'xBqPFcZ3Rfpy2eWDaWhCzHMHRBk',
#   'id': 'UgyKBsvQxhL6ckSeagF4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'CHPwQVsQEh66dtGFUofk_gYdIQA',
#     'id': 'UgyKBsvQxhL6ckSeagF4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Even though vaccinated people can still catch covid, become severely ill, die, and spread it, just like unvaccinated people... Always remember the vaccine is very effective!',
#      'textOriginal': 'Even though vaccinated people can still catch covid, become severely ill, die, and spread it, just like unvaccinated people... Always remember the vaccine is very effective!',
#      'authorDisplayName': 'Ivan L',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQiQXMxW9de35qOqwZ-e9xzxwx8-KJy7O2dP04k=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCFjgzpcI2pv7UrdIo0vSZWg',
#      'authorChannelId': {'value': 'UCFjgzpcI2pv7UrdIo0vSZWg'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T18:44:45Z',
#      'updatedAt': '2022-02-27T18:44:45Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'qIfP64reYNDjslcAS1km0QAqZJ8',
#   'id': 'Ugzj9wPUET76ZlNiXTd4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': '_dlSje3BEiaVxmdWkj98z5zW2xg',
#     'id': 'Ugzj9wPUET76ZlNiXTd4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Yes man. <br>Yes man.\xa0<br>Yes man.<br>Who do you think you are fooling, you FOOL?',
#      'textOriginal': 'Yes man. \nYes man.\xa0\nYes man.\nWho do you think you are fooling, you FOOL?',
#      'authorDisplayName': 'Christopher Dollbaum',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSHzo-p--sfrf6sQQlyQYW4p332ZQFo7y2kKTcJrnyryy8EZZLtOWJaudk2uoYQ=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCGehiLPFWzffC1TmoY4gQTQ',
#      'authorChannelId': {'value': 'UCGehiLPFWzffC1TmoY4gQTQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T18:43:34Z',
#      'updatedAt': '2022-02-27T18:43:34Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': '2VtHUOX87pi1Y_QSikb0aMbtsDM',
#   'id': 'UgyuiLBLJ3hZzXWkIVB4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'm6HKvqF2QzOLmEPbz_B-JgfPqN8',
#     'id': 'UgyuiLBLJ3hZzXWkIVB4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Of course there effective! There effective because I will not contaminate my body will!',
#      'textOriginal': 'Of course there effective! There effective because I will not contaminate my body will!',
#      'authorDisplayName': 'Shawn Jarman',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLS_FWzg_3LfrTReIrY8dTFdmFlfacqWSvW41w=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCIwGx9Igi_epHBSQ1RtAMWg',
#      'authorChannelId': {'value': 'UCIwGx9Igi_epHBSQ1RtAMWg'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T18:42:37Z',
#      'updatedAt': '2022-02-27T18:42:37Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'pNgZ8Q4R_lFTlNLEXFPCm7F9nW8',
#   'id': 'UgxCJuFi9NYccma6ush4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'sLGq8diJ269TQWRa1_J7LuKsLeo',
#     'id': 'UgxCJuFi9NYccma6ush4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Said the shill',
#      'textOriginal': 'Said the shill',
#      'authorDisplayName': 'Mdk1984',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLT93YvwUtQrMdQcF8ApUrbOg_PuFZeejvHE7PHkHD7Ylg5oKBMXb1FtX3TFyagX=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCaO_mf3Dudast5EvABb2MDQ',
#      'authorChannelId': {'value': 'UCaO_mf3Dudast5EvABb2MDQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T18:36:39Z',
#      'updatedAt': '2022-02-27T18:36:39Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': '3Gt2ND01z0sOzPFIEvXnuVbN0U8',
#   'id': 'UgwgmyeFdGDIWcfC2j14AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'Js5V6gE6R3VQcq1JJaPBWvdqYv0',
#     'id': 'UgwgmyeFdGDIWcfC2j14AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Sample size, time period controls,variables, standard deviations. Integrity vs career move. What changed his standard before confirmed position 🤔',
#      'textOriginal': 'Sample size, time period controls,variables, standard deviations. Integrity vs career move. What changed his standard before confirmed position 🤔',
#      'authorDisplayName': 'M.E. J',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSLt6VRk_rNXLHla_UjgfiiioKtJOqcmt62Rg=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCiyH6W2e33JQXj9h_TpiNLg',
#      'authorChannelId': {'value': 'UCiyH6W2e33JQXj9h_TpiNLg'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T18:32:14Z',
#      'updatedAt': '2022-02-27T18:33:03Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': '1KyhvEfBY2NZfOQWTLx-UTNkjuc',
#   'id': 'Ugwv-c8Rj7eP9DoW13x4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'DT5mJwCsQc3MNHRPt90-z6Csew4',
#     'id': 'Ugwv-c8Rj7eP9DoW13x4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'They literally do not stop transmission, by the CDC&#39;s own admission. Preventing transmission (leading to herd immunity) is the very basis for justifying mandates.',
#      'textOriginal': "They literally do not stop transmission, by the CDC's own admission. Preventing transmission (leading to herd immunity) is the very basis for justifying mandates.",
#      'authorDisplayName': 'TalesOf Gore',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQ9IX77_YWWT3tMnmRYDbR1jnGo_-C4kCG9=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCcZEEWUhHBeNX3DA9tSu_Xw',
#      'authorChannelId': {'value': 'UCcZEEWUhHBeNX3DA9tSu_Xw'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T18:32:12Z',
#      'updatedAt': '2022-02-27T18:32:12Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'oFQAlQVBG7QhsHNmG3ojyAPDOPE',
#   'id': 'UgwWXK9fCDdHz6H_4oN4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'z4_Wmhk8IzFC7Jz9ozQc8LVCy3s',
#     'id': 'UgwWXK9fCDdHz6H_4oN4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Shame on channel 10 for giving this quack a platform',
#      'textOriginal': 'Shame on channel 10 for giving this quack a platform',
#      'authorDisplayName': 'Wild1995',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRzeTFr7fxQgcPv1HNOiR0EXYjwpiGPFZQP4d40=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UC6I68YU_gCCnh-QoFo9eUVw',
#      'authorChannelId': {'value': 'UC6I68YU_gCCnh-QoFo9eUVw'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T18:29:07Z',
#      'updatedAt': '2022-02-27T18:29:07Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'xhGPCZcA9m_S5g9EndbNn_Fxv0U',
#   'id': 'UgzqVp3ztLkAvbzNhER4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'bHZ3blpaz3mLHpTabcjyzBJLDE4',
#     'id': 'UgzqVp3ztLkAvbzNhER4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'DOOOOOOOOOOOONNNTT YOOOOU BELIEEEEEEEEEEVE IIITTTTTTTTTTTTTTT!!!!!!!',
#      'textOriginal': 'DOOOOOOOOOOOONNNTT YOOOOU BELIEEEEEEEEEEVE IIITTTTTTTTTTTTTTT!!!!!!!',
#      'authorDisplayName': 'will Johnson',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQsMDo0dBbjDpDHgj1sXXnjOsT7Zuze-C8p7Q=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCSIvMfHiukwf7tMcspZL5NQ',
#      'authorChannelId': {'value': 'UCSIvMfHiukwf7tMcspZL5NQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T18:27:08Z',
#      'updatedAt': '2022-02-27T18:27:08Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'kEn5Y-5PZe4e1Sv9Oq_GziIGwp0',
#   'id': 'Ugwtb1VTNUKjD902s0p4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'yc8kqM8iY-a8Ry1DR7b_1PneR0g',
#     'id': 'Ugwtb1VTNUKjD902s0p4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Suuukkkkkkiiiiiiitt',
#      'textOriginal': 'Suuukkkkkkiiiiiiitt',
#      'authorDisplayName': 'Nonsense',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQC_Za8hlCq2NwY0W_U8YndPX5zi_HuYTIYaQ=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCbqhAI4mPb0hY6GuUQnV3HQ',
#      'authorChannelId': {'value': 'UCbqhAI4mPb0hY6GuUQnV3HQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T18:26:01Z',
#      'updatedAt': '2022-02-27T18:26:01Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'NnrWf98x0ooc1GOaa8hmG67YOZQ',
#   'id': 'UgwVXlfmlc6H1PwAUIp4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'Af78gOcqcwkKOHoR2wlrYMPsvnM',
#     'id': 'UgwVXlfmlc6H1PwAUIp4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': '🤥🤥🤥🤡🤡🤡',
#      'textOriginal': '🤥🤥🤥🤡🤡🤡',
#      'authorDisplayName': 'Love Oneanother',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/4e5JozgSlstWavsZlhK8d3oncOCif0Dhd-y25O-ey1n7aDcGpIC_z7f6N2seBnIfbrhhpzQG=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UC2qSQx0N7BqrUh8U9JDnCvA',
#      'authorChannelId': {'value': 'UC2qSQx0N7BqrUh8U9JDnCvA'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T18:25:04Z',
#      'updatedAt': '2022-02-27T18:25:04Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'Si3thFskaxkogPuJew0jvpDc_pU',
#   'id': 'Ugws-QyFxjrQmFHR1r94AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'ysJ0T8wnxbg8Ays9ruymupU74SU',
#     'id': 'Ugws-QyFxjrQmFHR1r94AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'How shocking it is, when an republicans appointed doctor, even admits that something like the covid vaccine with many billions of doses around the world, tracked by data, and the word of all the hospitals on the planet, is actually real. <br>Sorry Maga heads, vaccines ARE real. So are elections, climate change. Want to worry about something fake? You already are. Critical race theory in schools is a manufactured narrative. Election fraud is a fake narrative. How many recounts do you need?? <br>Trump has never been &quot;conservative&quot;. All 3 marriages cheated on, pays porn stars with campaign funds. Then turns around to the Christian wing and tells them how strong his faith is, while in real life if the casino-bankrupting junk bond selling multiple business fraud case losing real estate heir even went near a church he&#39;d probably burst into flame. Politician to the core, through bankruptcy after bankruptcy publicity is all he&#39;s ever really cared about his whole career. Politician to the core and the worst kind too.',
#      'textOriginal': 'How shocking it is, when an republicans appointed doctor, even admits that something like the covid vaccine with many billions of doses around the world, tracked by data, and the word of all the hospitals on the planet, is actually real. \nSorry Maga heads, vaccines ARE real. So are elections, climate change. Want to worry about something fake? You already are. Critical race theory in schools is a manufactured narrative. Election fraud is a fake narrative. How many recounts do you need?? \nTrump has never been "conservative". All 3 marriages cheated on, pays porn stars with campaign funds. Then turns around to the Christian wing and tells them how strong his faith is, while in real life if the casino-bankrupting junk bond selling multiple business fraud case losing real estate heir even went near a church he\'d probably burst into flame. Politician to the core, through bankruptcy after bankruptcy publicity is all he\'s ever really cared about his whole career. Politician to the core and the worst kind too.',
#      'authorDisplayName': 'NINO',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLR4XPr-QQFs9crYOi8PKoidVE785UmW6gqnZwMB=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UC3DOmc1FPF8iDf97zMpHj_g',
#      'authorChannelId': {'value': 'UC3DOmc1FPF8iDf97zMpHj_g'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T18:22:08Z',
#      'updatedAt': '2022-02-27T18:24:40Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'Ik48DeAbO522wXZd-wjFow989Ms',
#   'id': 'UgxMFHj_mV_aZ3Ru3rh4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'Pcg5cSvFaL9ccRQeXPILV0B_Ih0',
#     'id': 'UgxMFHj_mV_aZ3Ru3rh4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'It&#39;s very comical how far this made up manmade concoction virus has gone. <br>An idea that has been allowed to do all this damage and no one wants it to stop.   <br>Especially the vaccinated.  <br>The vaccinated like this game.',
#      'textOriginal': "It's very comical how far this made up manmade concoction virus has gone. \nAn idea that has been allowed to do all this damage and no one wants it to stop.   \nEspecially the vaccinated.  \nThe vaccinated like this game.",
#      'authorDisplayName': 'eyemNew',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLR4M0SLHmxROaOoIT-SBg0o_Sg2dJ2P6w5VF7U0vBKGWmqKgkR_vN0kh9zkevsa=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UC1mzjsMYPVWFpOZ0OUbYKeg',
#      'authorChannelId': {'value': 'UC1mzjsMYPVWFpOZ0OUbYKeg'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T18:22:03Z',
#      'updatedAt': '2022-02-27T18:22:03Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'NBLghxPMb-QevqmU_k9gVMe8IBc',
#   'id': 'Ugym2G6apG9qguNxf4R4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': '3WeUco0w9I7dijQywtVSPdC2Zk8',
#     'id': 'Ugym2G6apG9qguNxf4R4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'This statement brought to you by Pfizer...',
#      'textOriginal': 'This statement brought to you by Pfizer...',
#      'authorDisplayName': 'Mishn0',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTt2xRcysMvc0JO8ymlEjZFGNYd5VBtWBtHDhYo=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCuhA6Xc38EcE1B-prHGlhMw',
#      'authorChannelId': {'value': 'UCuhA6Xc38EcE1B-prHGlhMw'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T18:16:10Z',
#      'updatedAt': '2022-02-27T18:16:10Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'CB57KakTXrpHUWj9DU3skgOGUEk',
#   'id': 'Ugy1n2ejHG1Lna5NyMV4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'dWkpOtqOZL1Q3_pOiUmrnSBl47A',
#     'id': 'Ugy1n2ejHG1Lna5NyMV4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'How did this happen?',
#      'textOriginal': 'How did this happen?',
#      'authorDisplayName': 'Pacer Ts',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRVLgffhQRmWrL6OYoctugP9mRxP57pqmnfIv1k_-upWnCm1x37F3VbzdbGsLt5=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCmE06qOBYfU6TvlXhIpnqhg',
#      'authorChannelId': {'value': 'UCmE06qOBYfU6TvlXhIpnqhg'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T18:15:09Z',
#      'updatedAt': '2022-02-27T18:15:09Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'cuBqBUd-LLgFRsUeVU4633bmdM8',
#   'id': 'UgyfQf8MM1zLC6pPY0t4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'u8KgNUJNhNfjpYcGnpUTs5XujSY',
#     'id': 'UgyfQf8MM1zLC6pPY0t4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Fear mongering liars!',
#      'textOriginal': 'Fear mongering liars!',
#      'authorDisplayName': 'james',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTevgHChDGS5gMtNJfqGCURVH27HrZL8oZwWMBslA=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCJW_WmFXpWe2Al4PxvFjcEg',
#      'authorChannelId': {'value': 'UCJW_WmFXpWe2Al4PxvFjcEg'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T18:12:23Z',
#      'updatedAt': '2022-02-27T18:12:23Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': '-Bh6_J0kwRHDGht3vtecVg4TVJ0',
#   'id': 'UgwSzEoC6U5xJXIWzkx4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'Rh1HycmO4yIAL43lvIjnOg8nyLY',
#     'id': 'UgwSzEoC6U5xJXIWzkx4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'He&#39;s not brand new, he&#39;s been around almost half a year plus. He&#39;s awesome!',
#      'textOriginal': "He's not brand new, he's been around almost half a year plus. He's awesome!",
#      'authorDisplayName': 'Matthew King',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLS__l10Uzd_lrmT_Cf9N3LMPm6sWS1zh2Ah2A=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCQp3p90MWQ08T8p2PdqaZmA',
#      'authorChannelId': {'value': 'UCQp3p90MWQ08T8p2PdqaZmA'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T18:11:35Z',
#      'updatedAt': '2022-02-27T18:11:35Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'HdYMSkwQXBYJBECoCVSfiXpT_po',
#   'id': 'UgzMNiZdSx5dLg2HTSZ4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'nBVMdeHGzfF3e_3V7BHOPfPCZhQ',
#     'id': 'UgzMNiZdSx5dLg2HTSZ4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Maybe, but not as effective as getting the virus and developing natural immunity (which is stronger and lasts longer).  Since it has a 99.9% survival rate if you&#39;re under 65, maybe give that a try.....',
#      'textOriginal': "Maybe, but not as effective as getting the virus and developing natural immunity (which is stronger and lasts longer).  Since it has a 99.9% survival rate if you're under 65, maybe give that a try.....",
#      'authorDisplayName': 'S Des',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTvDES7LAfVXO3nB6ZhR4bSobk45fG5z7YSnACtRg=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCM_uYPuiCoewxlNWqV5G9Wg',
#      'authorChannelId': {'value': 'UCM_uYPuiCoewxlNWqV5G9Wg'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T18:10:57Z',
#      'updatedAt': '2022-02-27T18:10:57Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'v3MALn4EaupxH5X5WZ9cve2qdo0',
#   'id': 'UgziLpyvLxXKVHHwv6J4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'cQOC6vaJD2xvnSuizinytqeYMfs',
#     'id': 'UgziLpyvLxXKVHHwv6J4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'He&#39;s right.  Also eating nothing but candy for a week is great for your complection.',
#      'textOriginal': "He's right.  Also eating nothing but candy for a week is great for your complection.",
#      'authorDisplayName': 'mixboy79',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSL97U9y-Z_1lq5KJJ_Zw6166AE6SELq9avGA=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCxLURkEzks6FvYDQZ2fJ2FA',
#      'authorChannelId': {'value': 'UCxLURkEzks6FvYDQZ2fJ2FA'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 4,
#      'publishedAt': '2022-02-27T18:06:48Z',
#      'updatedAt': '2022-02-27T18:06:48Z'}},
#    'canReply': True,
#    'totalReplyCount': 4,
#    'isPublic': True},
#   'replies': {'comments': [{'kind': 'youtube#comment',
#      'etag': 'tqqV5I7yLS9vOalmKDd7M0GQWwE',
#      'id': 'UgziLpyvLxXKVHHwv6J4AaABAg.9YxsjxykaNH9YyFRCyCN7d',
#      'snippet': {'videoId': 'z_d5Kq2DwTI',
#       'textDisplay': '@Sia Henderson no kidding 😂',
#       'textOriginal': '@Sia Henderson no kidding 😂',
#       'parentId': 'UgziLpyvLxXKVHHwv6J4AaABAg',
#       'authorDisplayName': 'Geoffrey Lyons',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTqv1cYVP2e_n1zB1eNqrytSspjVnLw0yYwhjPlXQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCzDncreS5MzFotwafqrtGWA',
#       'authorChannelId': {'value': 'UCzDncreS5MzFotwafqrtGWA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-02-27T21:33:49Z',
#       'updatedAt': '2022-02-27T21:33:49Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'nTJEIWywXhbQI7jgL-wUHgZ5Ooc',
#      'id': 'UgziLpyvLxXKVHHwv6J4AaABAg.9YxsjxykaNH9YyCIjQL6Cp',
#      'snippet': {'videoId': 'z_d5Kq2DwTI',
#       'textDisplay': '@Geoffrey Lyons The poor things 🤣🤣🤣',
#       'textOriginal': '@Geoffrey Lyons The poor things 🤣🤣🤣',
#       'parentId': 'UgziLpyvLxXKVHHwv6J4AaABAg',
#       'authorDisplayName': 'Sia Henderson',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/v1xCy_RCABlm-EekpQK_3C2GtZLCLwOXksh_7o_eaKq9-QkVZgXAbMavMpI5LwjxfwKx2Tnmzg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCLQwZOWqn6pTpoWJ4IRDmbQ',
#       'authorChannelId': {'value': 'UCLQwZOWqn6pTpoWJ4IRDmbQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-02-27T21:06:26Z',
#       'updatedAt': '2022-02-27T21:06:26Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'B-b2cdgdRfSMpJ64I0zx_31q3dM',
#      'id': 'UgziLpyvLxXKVHHwv6J4AaABAg.9YxsjxykaNH9YyBGLUJS_4',
#      'snippet': {'videoId': 'z_d5Kq2DwTI',
#       'textDisplay': '@Sia Henderson <br>Hahaha … most commenters are semi literate!',
#       'textOriginal': '@Sia Henderson \nHahaha … most commenters are semi literate!',
#       'parentId': 'UgziLpyvLxXKVHHwv6J4AaABAg',
#       'authorDisplayName': 'Geoffrey Lyons',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTqv1cYVP2e_n1zB1eNqrytSspjVnLw0yYwhjPlXQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCzDncreS5MzFotwafqrtGWA',
#       'authorChannelId': {'value': 'UCzDncreS5MzFotwafqrtGWA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-02-27T20:57:22Z',
#       'updatedAt': '2022-02-27T20:57:22Z'}},
#     {'kind': 'youtube#comment',
#      'etag': '30UuR2Kge5Hs0hoBxPkKAqWMGgo',
#      'id': 'UgziLpyvLxXKVHHwv6J4AaABAg.9YxsjxykaNH9Yy8nr0f0TU',
#      'snippet': {'videoId': 'z_d5Kq2DwTI',
#       'textDisplay': 'And reading is fundamental....<br><br>*COMPLEXION',
#       'textOriginal': 'And reading is fundamental....\n\n*COMPLEXION',
#       'parentId': 'UgziLpyvLxXKVHHwv6J4AaABAg',
#       'authorDisplayName': 'Sia Henderson',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/v1xCy_RCABlm-EekpQK_3C2GtZLCLwOXksh_7o_eaKq9-QkVZgXAbMavMpI5LwjxfwKx2Tnmzg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCLQwZOWqn6pTpoWJ4IRDmbQ',
#       'authorChannelId': {'value': 'UCLQwZOWqn6pTpoWJ4IRDmbQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-02-27T20:35:52Z',
#       'updatedAt': '2022-02-27T20:35:52Z'}}]}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'ANgrhHaSGXyMLDhGSyAlcieItyo',
#   'id': 'Ugy5hDnYfNFHpAEmWpd4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'Ie1SkADbTDNrYTB-UI25fqkXr1Q',
#     'id': 'Ugy5hDnYfNFHpAEmWpd4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Tell this to all the vaccinated people that got covid.',
#      'textOriginal': 'Tell this to all the vaccinated people that got covid.',
#      'authorDisplayName': 'America 1st',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRqtgRozMq89h68CDpAbs00ve80Zkf8kL_mEw=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCBYZUkzrGAcxZkevzYUtNCA',
#      'authorChannelId': {'value': 'UCBYZUkzrGAcxZkevzYUtNCA'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T18:05:11Z',
#      'updatedAt': '2022-02-27T18:05:11Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'XnLhs2vluHZHP2q3l3va0-5w6kY',
#   'id': 'UgxKBXZkww8ICkm-ryN4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'FLs5Mj0Eqw66OTj4sYurxm6uNNk',
#     'id': 'UgxKBXZkww8ICkm-ryN4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'About has helpful as people&#39;s eyes.. Why are Africans in the stone age all over the world where isolated with no fire making skills unless taught while neanderthals mastered fire making? <b>Points at skin</b> We MADE THEM everything they are, and that&#39;s why CCP will exterminate them all if they win. CCP doesn&#39;t want us feeding &amp; elevating anyone but THEM. WORLD SCIENCE.. Conditions by racial majority on Earth. &lt; BUT BUT!! ITS RACISM!! If they&#39;re like that in CAUCASIAN MADE NATIONS!! LOL! - ATHEIST EUGENICIST',
#      'textOriginal': "About has helpful as people's eyes.. Why are Africans in the stone age all over the world where isolated with no fire making skills unless taught while neanderthals mastered fire making? *Points at skin* We MADE THEM everything they are, and that's why CCP will exterminate them all if they win. CCP doesn't want us feeding & elevating anyone but THEM. WORLD SCIENCE.. Conditions by racial majority on Earth. < BUT BUT!! ITS RACISM!! If they're like that in CAUCASIAN MADE NATIONS!! LOL! - ATHEIST EUGENICIST",
#      'authorDisplayName': 'Mr.Quick',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQkhC_gKQhTG_eWibPAthh4FGLGwv1nGA62WHkwlQ=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCu3qPmJFf8ag9spfRXYNX6A',
#      'authorChannelId': {'value': 'UCu3qPmJFf8ag9spfRXYNX6A'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T17:58:02Z',
#      'updatedAt': '2022-02-27T17:58:02Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': '2VNYCUx-bmwkmrdQ7bydAUVOyM4',
#   'id': 'Ugzo_x_2MnurIQ4I9854AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'UmlLmzbAkDHo_saygjUuZODYH1M',
#     'id': 'Ugzo_x_2MnurIQ4I9854AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': '161 like to 497 dislikes.... Maybe the news needs to wake up a bit.  Nobody believes you any longer.',
#      'textOriginal': '161 like to 497 dislikes.... Maybe the news needs to wake up a bit.  Nobody believes you any longer.',
#      'authorDisplayName': 'uw91',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTygZq4QsmdRDGAg9ZOijWHrt0UBDMmj8FILw=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCmUMUHhaml4jxp_RRLt3bgg',
#      'authorChannelId': {'value': 'UCmUMUHhaml4jxp_RRLt3bgg'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T17:57:40Z',
#      'updatedAt': '2022-02-27T17:57:40Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'bLlBcM5rBlhQ-wWEJDthC28-Pak',
#   'id': 'UgyImgU5e0uJiCVsK2F4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'XlPaW-y8LdSwmb71kGNEvkoCtDQ',
#     'id': 'UgyImgU5e0uJiCVsK2F4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Didn&#39;t you get the message from your producers? COVID is out, Ukraine is in! It&#39;s okay you can stop the theater now. ❤️',
#      'textOriginal': "Didn't you get the message from your producers? COVID is out, Ukraine is in! It's okay you can stop the theater now. ❤️",
#      'authorDisplayName': 'staycold',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/RT-yK-mfP71HmhOmufkHoF9JShGqdbRxsx9IX5mbZ_QBJ4FbJeh8FXmJxCdfl06I6t8a-Xr3AQ=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCt5Z2uzVYBqobvz4yAN4A9g',
#      'authorChannelId': {'value': 'UCt5Z2uzVYBqobvz4yAN4A9g'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 1,
#      'publishedAt': '2022-02-27T17:56:29Z',
#      'updatedAt': '2022-02-27T17:56:29Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'S0t8kiREONIwyGOtbYFL8l1kUsE',
#   'id': 'Ugz6glGZifExEieOy5l4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': '24zvWYEYLW1mKJCJoLpxB1pKWTQ',
#     'id': 'Ugz6glGZifExEieOy5l4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'If you say a lie long enough, it&#39;s eventually considered truth. I guess they&#39;re going with that approach instead of just making it effective.',
#      'textOriginal': "If you say a lie long enough, it's eventually considered truth. I guess they're going with that approach instead of just making it effective.",
#      'authorDisplayName': 'Logan Pedroza',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRmAxOaB6TXk3A0qFRrDyrE72DDViaAL8JBHw=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCPag-nR3-5987rUIeFKPGMQ',
#      'authorChannelId': {'value': 'UCPag-nR3-5987rUIeFKPGMQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 2,
#      'publishedAt': '2022-02-27T17:55:45Z',
#      'updatedAt': '2022-02-27T17:55:45Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'KKKVd-3ifdfqOQZwyOv66svxop0',
#   'id': 'UgwUf82h0e712Ujrjwh4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'JW6gzWNdy0so5bPKUStEmF7WVVI',
#     'id': 'UgwUf82h0e712Ujrjwh4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Get rid of him he is a yes man',
#      'textOriginal': 'Get rid of him he is a yes man',
#      'authorDisplayName': 'Roger Metz',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSMwwTAnG3cCdV1NY3ALBqRXFM9gvQQeIqV5A=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCIjfrz0RdbKHsmlpTkmbaew',
#      'authorChannelId': {'value': 'UCIjfrz0RdbKHsmlpTkmbaew'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T17:51:50Z',
#      'updatedAt': '2022-02-27T17:51:50Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'Shogk9IrNp0GB-LTAuLlSvfiGDk',
#   'id': 'Ugyy5u8kKIHXg7ASOId4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'SRu8YT785ieMcRwPCCnlr8nWWoc',
#     'id': 'Ugyy5u8kKIHXg7ASOId4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Only for the first covid',
#      'textOriginal': 'Only for the first covid',
#      'authorDisplayName': 'I miss the 80s😎',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/MVpo_7t6j_LRJpD6TukpFHhRjUAiYkw0i68gvL5O9Y_ds4o7RTeewrfqasHgP3RySUP2gLbqfg=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCjqzWghvf7Sttcx6Ei3XdmQ',
#      'authorChannelId': {'value': 'UCjqzWghvf7Sttcx6Ei3XdmQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 1,
#      'publishedAt': '2022-02-27T17:48:07Z',
#      'updatedAt': '2022-02-27T17:48:07Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'wChfGZQ_7EZc_Y5YTAgLyT9k81w',
#   'id': 'UgxQokqUaAZQuarawpZ4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'imP42PquLheToFkmLb9qbVyz0II',
#     'id': 'UgxQokqUaAZQuarawpZ4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Looks like the Florida Surgeon General just got fired by Death Sentence DeSantis LOL how dare he even say the covid exists !',
#      'textOriginal': 'Looks like the Florida Surgeon General just got fired by Death Sentence DeSantis LOL how dare he even say the covid exists !',
#      'authorDisplayName': "Big D's Gaming ",
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ZLQVThkOPqn-yuUb7pRtyTx-6_m1_wxvqTzhqLE7z0dyNkDbEkzP-GjPH0Wu25YgG2aQTS1S8g=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCp10-oMcH7Q7As97SXFj4EA',
#      'authorChannelId': {'value': 'UCp10-oMcH7Q7As97SXFj4EA'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T17:38:34Z',
#      'updatedAt': '2022-02-27T17:38:34Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': '3-H76zlDi7-ISfykzb3wUIf6cEU',
#   'id': 'Ugz4ZvAH8hKvzJ8LH9F4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'x7g6S4_nsBGpEBeOGcsNNCQr3N8',
#     'id': 'Ugz4ZvAH8hKvzJ8LH9F4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'They&#39;re effective- but to what cost? To what risk? Covid has it&#39;s own set of risks.... a vaccine does not come as a golden ticket. For some it may be worth it and for others it may not be worth it. And that&#39;s the beauty of freedom... I will protect my health as I see best, and you protect your health as you see best.',
# ...
#      'authorDisplayName': 'AnToeKnee',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/AUUwtm_TFGm23vK3X2y2tk-YTiu7JNxEfi-Nm9GBwneOQb8bhfiQ2PdIajMt4St6s2k0OwJlFA=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCHrkXJLY5nOAnq9jUmT2png',
#      'authorChannelId': {'value': 'UCHrkXJLY5nOAnq9jUmT2png'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T16:50:54Z',
#      'updatedAt': '2022-02-27T16:50:54Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': '_CmLkSnv3eusjI_BBZL3OftpEmo',
#   'id': 'UgwQBCSY8WKD_TLv6K14AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'jIqrFcLIiXi4uNIiFKgLqfADy5o',
#     'id': 'UgwQBCSY8WKD_TLv6K14AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Effective at what?',
#      'textOriginal': 'Effective at what?',
#      'authorDisplayName': 'Ravens Edge',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTChsuR9u24Ic2kRsgYIFFrhLjE-Z7atRm9n3nVlQ=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UChfnLh0M1BPsbNf14z6Xhdw',
#      'authorChannelId': {'value': 'UChfnLh0M1BPsbNf14z6Xhdw'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T16:47:59Z',
#      'updatedAt': '2022-02-27T16:47:59Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'VNM56TJ5P5Pqf-GoFTzr-pweocY',
#   'id': 'UgwoNP5Ck5o_ivzO8bV4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'o5NSXEf5T7bWAMVX9XyrKXXFzUE',
#     'id': 'UgwoNP5Ck5o_ivzO8bV4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Pain pills r safe n effective too, rite ?',
#      'textOriginal': 'Pain pills r safe n effective too, rite ?',
#      'authorDisplayName': 'Melissa Cavanaugh',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTPmfyESt16-W7vXJQcLZsOWVjfGKtMi6Nx5w=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCx8_Jau61FUMiz4wvr10qHQ',
#      'authorChannelId': {'value': 'UCx8_Jau61FUMiz4wvr10qHQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T16:47:13Z',
#      'updatedAt': '2022-02-27T16:47:13Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'vb7rlIY8_chutZEczlf8y8sZtjA',
#   'id': 'Ugx68c4rjx_ovNTt1tF4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'kOjCCYBfPjhJ2SeP6IGqydh-zB8',
#     'id': 'Ugx68c4rjx_ovNTt1tF4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'I guess you can say that 8% effective is still better than 7% effective.',
#      'textOriginal': 'I guess you can say that 8% effective is still better than 7% effective.',
#      'authorDisplayName': 'Paul M',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSg0q712gJX67tr07r3C2Oze4PWmUQ7_nSXt77G1Jw_HTFIIjRQRmF-qpHbhQ0w=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCxk-x1Y1Y9wM4db4W4jd0gg',
#      'authorChannelId': {'value': 'UCxk-x1Y1Y9wM4db4W4jd0gg'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 6,
#      'publishedAt': '2022-02-27T16:47:08Z',
#      'updatedAt': '2022-02-27T16:47:08Z'}},
#    'canReply': True,
#    'totalReplyCount': 4,
#    'isPublic': True},
#   'replies': {'comments': [{'kind': 'youtube#comment',
#      'etag': 'VAzGRYmzsIOqW2Ddu1xUJlh3Slw',
#      'id': 'Ugx68c4rjx_ovNTt1tF4AaABAg.9YxjcZ2Txk19Yxxx86zpiF',
#      'snippet': {'videoId': 'z_d5Kq2DwTI',
#       'textDisplay': '@eyemNew WTF are you talking about? all life is temporary! are you saying the covid vaccine prevents immortality?',
#       'textOriginal': '@eyemNew WTF are you talking about? all life is temporary! are you saying the covid vaccine prevents immortality?',
#       'parentId': 'Ugx68c4rjx_ovNTt1tF4AaABAg',
#       'authorDisplayName': 'James Ferrell',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSJ--yli8wIaIRkdVOSlwNro430viVpFl4M9w=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC3VnmM-VzFWC3zWXSUZY0Xw',
#       'authorChannelId': {'value': 'UC3VnmM-VzFWC3zWXSUZY0Xw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-02-27T18:52:17Z',
#       'updatedAt': '2022-02-27T18:52:17Z'}},
#     {'kind': 'youtube#comment',
#      'etag': '5I2rhMyjVm0iNYOQ8wiVLFRJ0pA',
#      'id': 'Ugx68c4rjx_ovNTt1tF4AaABAg.9YxjcZ2Txk19YxxOHH1P_e',
#      'snippet': {'videoId': 'z_d5Kq2DwTI',
#       'textDisplay': '@James Ferrell <br>There are 2 guarantees in this life...<br>This temporary life<br>And the permanent life',
#       'textOriginal': '@James Ferrell \nThere are 2 guarantees in this life...\nThis temporary life\nAnd the permanent life',
#       'parentId': 'Ugx68c4rjx_ovNTt1tF4AaABAg',
#       'authorDisplayName': 'eyemNew',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLR4M0SLHmxROaOoIT-SBg0o_Sg2dJ2P6w5VF7U0vBKGWmqKgkR_vN0kh9zkevsa=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC1mzjsMYPVWFpOZ0OUbYKeg',
#       'authorChannelId': {'value': 'UC1mzjsMYPVWFpOZ0OUbYKeg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-02-27T18:47:23Z',
#       'updatedAt': '2022-02-27T18:47:23Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'L0CW4cOunG7CR6P9BaCZR8v_-Go',
#      'id': 'Ugx68c4rjx_ovNTt1tF4AaABAg.9YxjcZ2Txk19YxwfBKCeuk',
#      'snippet': {'videoId': 'z_d5Kq2DwTI',
#       'textDisplay': 'Ya dude everyone dies eventually 😭😂 only guarantee in life is death',
#       'textOriginal': 'Ya dude everyone dies eventually 😭😂 only guarantee in life is death',
#       'parentId': 'Ugx68c4rjx_ovNTt1tF4AaABAg',
#       'authorDisplayName': 'James Ferrell',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSJ--yli8wIaIRkdVOSlwNro430viVpFl4M9w=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC3VnmM-VzFWC3zWXSUZY0Xw',
#       'authorChannelId': {'value': 'UC3VnmM-VzFWC3zWXSUZY0Xw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-02-27T18:41:06Z',
#       'updatedAt': '2022-02-27T18:41:06Z'}},
#     {'kind': 'youtube#comment',
#      'etag': 'suUbAFeP-uWmgNyclxz0anMxHyE',
#      'id': 'Ugx68c4rjx_ovNTt1tF4AaABAg.9YxjcZ2Txk19YxqONj2YOQ',
#      'snippet': {'videoId': 'z_d5Kq2DwTI',
#       'textDisplay': 'It seems the way things have been going and the way things are the only thing that is 100% guaranteed is death.  <br>Within the next 15 minutes 50 million people will die, then after that 15 minutes another 60 million people will die then after that 11 million people will die.  <br>How do they keep up with these death counts so quickly....<br>I can&#39;t even keep up with the Smith&#39;s Jones&#39; and McCormick&#39;s.',
#       'textOriginal': "It seems the way things have been going and the way things are the only thing that is 100% guaranteed is death.  \nWithin the next 15 minutes 50 million people will die, then after that 15 minutes another 60 million people will die then after that 11 million people will die.  \nHow do they keep up with these death counts so quickly....\nI can't even keep up with the Smith's Jones' and McCormick's.",
#       'parentId': 'Ugx68c4rjx_ovNTt1tF4AaABAg',
#       'authorDisplayName': 'eyemNew',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLR4M0SLHmxROaOoIT-SBg0o_Sg2dJ2P6w5VF7U0vBKGWmqKgkR_vN0kh9zkevsa=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC1mzjsMYPVWFpOZ0OUbYKeg',
#       'authorChannelId': {'value': 'UC1mzjsMYPVWFpOZ0OUbYKeg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-02-27T17:46:14Z',
#       'updatedAt': '2022-02-27T17:46:14Z'}}]}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'Hf9blMs60noSrvbzgMX3tiHOgrc',
#   'id': 'Ugwyw9E8jqvCnXUHZ2R4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'Oaij74OY6LD7pDrEVAGKaUh6xz0',
#     'id': 'Ugwyw9E8jqvCnXUHZ2R4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Effective in making people ill.',
#      'textOriginal': 'Effective in making people ill.',
#      'authorDisplayName': 'zebageba',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSwb7PfmHXQn0YlbDiL5qn3x0iU4VtYQOtV-LJ-=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCOaI4zN5XGwCnRja4lf7WIQ',
#      'authorChannelId': {'value': 'UCOaI4zN5XGwCnRja4lf7WIQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T16:45:09Z',
#      'updatedAt': '2022-02-27T16:45:09Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'yDkkowczsL3usrhsZPD6m66DraM',
#   'id': 'Ugx6Ev4DsnGX-68iFW14AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'iUbUCGhDjh0bLCvW2mpQi5Ab7Rk',
#     'id': 'Ugx6Ev4DsnGX-68iFW14AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'So effective that, if the first one doesn&#39;t work, they have a second, and if the second doesn&#39;t work, they have a third, and if the third one doesn&#39;t work, they have a fourth. To be continued....',
#      'textOriginal': "So effective that, if the first one doesn't work, they have a second, and if the second doesn't work, they have a third, and if the third one doesn't work, they have a fourth. To be continued....",
#      'authorDisplayName': 'Russ Ingersoll',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQ-NDz5pzloNKjMowY-shj422AexcSqFtYvBawi=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCezue7mTn1q9nBciALfUnxw',
#      'authorChannelId': {'value': 'UCezue7mTn1q9nBciALfUnxw'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 4,
#      'publishedAt': '2022-02-27T16:43:43Z',
#      'updatedAt': '2022-02-27T16:43:43Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'uoCgyk59IpmRoupTApsiN3LzEfs',
#   'id': 'UgyLWdSHgMY4VNH9-s94AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'TyWaNgnRy_bP90eGGcisd16sviM',
#     'id': 'UgyLWdSHgMY4VNH9-s94AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Effective? Why are people getting so called break through cases? Come on. Should not be getting it at all.',
#      'textOriginal': 'Effective? Why are people getting so called break through cases? Come on. Should not be getting it at all.',
#      'authorDisplayName': 'Cynthia Cronin',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRXuYTP32dvzQAIQcKavos1mLIaQ6LdJux2ag=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCq2p_z3_qRSozyUphvnEdlQ',
#      'authorChannelId': {'value': 'UCq2p_z3_qRSozyUphvnEdlQ'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 1,
#      'publishedAt': '2022-02-27T16:42:33Z',
#      'updatedAt': '2022-02-27T16:42:33Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'XubbQcCbqWLkGTi1PYyk0e_x0B4',
#   'id': 'UgwXN-81D6gOVatComt4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'mFvgpqSkR9ZrJOb7UggkdVktw28',
#     'id': 'UgwXN-81D6gOVatComt4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Are we still doing this',
#      'textOriginal': 'Are we still doing this',
#      'authorDisplayName': 'Dru Dru',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLSNrFtBpmk5IIAFXEGPpuY9Vy4xmK-d9Vqwog=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCy5n-3OyJw2veFEn__yw0Eg',
#      'authorChannelId': {'value': 'UCy5n-3OyJw2veFEn__yw0Eg'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T16:42:30Z',
#      'updatedAt': '2022-02-27T16:42:30Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}},
#  {'kind': 'youtube#commentThread',
#   'etag': '2WyUQd23TH2E1wMEoefNQDTU0Tk',
#   'id': 'Ugxp5mnffQq-kRpabWB4AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'u6VjrTqeTOBZ_Z3H_L9WI3aSyv8',
#     'id': 'Ugxp5mnffQq-kRpabWB4AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'Ah SHUTUP already, its over, the gig is up you stupid liars....when the pendulum swings back and we the people retake our government from you traitors, there will be Nuremberg trials, including the complicit media....have a nice day.,..but keep digging yourselves deeper though.',
#      'textOriginal': 'Ah SHUTUP already, its over, the gig is up you stupid liars....when the pendulum swings back and we the people retake our government from you traitors, there will be Nuremberg trials, including the complicit media....have a nice day.,..but keep digging yourselves deeper though.',
#      'authorDisplayName': 'Randy-Tzu',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLR3lvaGlKQRNpuM7InnEP-qcAwiphoYwe48fGKG=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UC5SdM_fOiITEgkMpWJ893yw',
#      'authorChannelId': {'value': 'UC5SdM_fOiITEgkMpWJ893yw'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T16:39:46Z',
#      'updatedAt': '2022-02-27T16:39:46Z'}},
#    'canReply': True,
#    'totalReplyCount': 1,
#    'isPublic': True},
#   'replies': {'comments': [{'kind': 'youtube#comment',
#      'etag': '8GlaOzaQTakA9HQ8_q_PibZhOr4',
#      'id': 'Ugxp5mnffQq-kRpabWB4AaABAg.9YximakQaOS9Yxj7j-2LeH',
#      'snippet': {'videoId': 'z_d5Kq2DwTI',
#       'textDisplay': 'Go to Russia please!!!!! Please 🥺🥺 that&#39;s where you belong',
#       'textOriginal': "Go to Russia please!!!!! Please 🥺🥺 that's where you belong",
#       'parentId': 'Ugxp5mnffQq-kRpabWB4AaABAg',
#       'authorDisplayName': 'HELPME100',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQnWgFsc5HwaREpBeSviG8nZdsBfiR76NB6Cx273w=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCQTvYiPgqQnvSWX0wjc3WYA',
#       'authorChannelId': {'value': 'UCQTvYiPgqQnvSWX0wjc3WYA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-02-27T16:42:48Z',
#       'updatedAt': '2022-02-27T16:42:48Z'}}]}},
#  {'kind': 'youtube#commentThread',
#   'etag': 'euMV15rwMXMlQro4vLlEyP0t7Hw',
#   'id': 'Ugw1EmrC76mCbeA6V894AaABAg',
#   'snippet': {'videoId': 'z_d5Kq2DwTI',
#    'topLevelComment': {'kind': 'youtube#comment',
#     'etag': 'TTxYA6WbOFA3Zh9sMJEJqSWOXUk',
#     'id': 'Ugw1EmrC76mCbeA6V894AaABAg',
#     'snippet': {'videoId': 'z_d5Kq2DwTI',
#      'textDisplay': 'LOL',
#      'textOriginal': 'LOL',
#      'authorDisplayName': 'InterWebGuy99',
#      'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRY9z2-vvBF-E40HxYrLWvpQu-ZoyRG6Y1yY7bg=s48-c-k-c0x00ffffff-no-rj',
#      'authorChannelUrl': 'http://www.youtube.com/channel/UCtZgTifAxHUktYlSmYcuBLw',
#      'authorChannelId': {'value': 'UCtZgTifAxHUktYlSmYcuBLw'},
#      'canRate': True,
#      'viewerRating': 'none',
#      'likeCount': 0,
#      'publishedAt': '2022-02-27T16:39:44Z',
#      'updatedAt': '2022-02-27T16:39:44Z'}},
#    'canReply': True,
#    'totalReplyCount': 0,
#    'isPublic': True}}]
